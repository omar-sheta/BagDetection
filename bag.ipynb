# %%
# !pip install roboflow torch torchvision
# Out:
# ...
#   Using cached certifi-2023.7.22-py3-none-any.whl.metadata (2.2 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 644.2 kB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 2.7 MB/s eta 0:00:00
# ...
#   Using cached tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 351.3 kB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 453.7 kB/s eta 0:00:00a 0:00:01
# Using cached certifi-2023.7.22-py3-none-any.whl (158 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 MB 1.7 MB/s eta 0:00:0000:0100:010m
# Using cached tqdm-4.66.1-py3-none-any.whl (78 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 1.8 MB/s eta 0:00:00ta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 3.8 MB/s eta 0:00:0000:0100:01
# ...

# %%
# REPLACE with your custom code snippet generated above

from roboflow import Roboflow
rf = Roboflow(api_key="QvwbepWEMdJI642UZL04")
project = rf.workspace().project("find-luggage")
model = project.version(1).model

# # infer on a local image
# print(model.predict("test.png", confidence=40, overlap=30).json())

# visualize your prediction
model.predict("test.png", confidence=40, overlap=30).save("prediction.jpg")

# infer on an image hosted elsewhere
# print(model.predict("URL_OF_YOUR_IMAGE", hosted=True, confidence=40, overlap=30).json())
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# how to save the model locally
model.save_locally("model.pt")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 # how to save the model locally
# ----> 2 model.save_locally("model.pt")
#
# AttributeError: 'ObjectDetectionModel' object has no attribute 'save_locally'

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="QvwbepWEMdJI642UZL04")
project = rf.workspace("findluggage").project("find-luggage")
dataset = project.version(1).download("yolov8")
# Out:
# retrying...
# loading Roboflow workspace...
# loading Roboflow project...
# [WARNING] we noticed you are downloading a `yolov8` datasets but you don't have `ultralytics` installed. Roboflow `.deploy` supports only models trained with `ultralytics==8.0.196`, to intall it `pip install ultralytics==8.0.196`.
# ...
# Extracting Dataset Version Zip to find-luggage-1 in yolov8:: 100%|██████████| 206/206 [00:00<00:00, 758.52it/s]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 2
#       1 # save the dataset to a local directory
# ----> 2 dataset.save("find-luggage-dataset")
#
# AttributeError: 'Dataset' object has no attribute 'save'

# %%
# %pip install ultralytics==8.0.196
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 631.1/631.1 kB 2.4 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.7/54.7 MB 7.0 MB/s eta 0:00:0000:0100:01
# DEPRECATION: pyodbc 4.0.0-unsupported has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pyodbc or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
# ...
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# print tree structure of this directory find-luggage-1 
# !tree -d find-luggage-1
# print everything in this directory find-luggage-1
# !ls -la find-luggage-1
# Out:
# total 40
# drwxr-xr-x@ 9 Omar  staff   288 Dec 29 22:14 .
# drwxr-xr-x@ 9 Omar  staff   288 Dec 29 22:14 ..
# -rw-r--r--@ 1 Omar  staff  6148 Dec 29 22:16 .DS_Store
# -rw-r--r--  1 Omar  staff   140 Dec 29 22:07 README.dataset.txt
# -rw-r--r--  1 Omar  staff   990 Dec 29 22:07 README.roboflow.txt
# -rw-r--r--  1 Omar  staff   279 Dec 29 22:07 data.yaml
# drwxr-xr-x@ 5 Omar  staff   160 Dec 29 22:14 test
# drwxr-xr-x@ 4 Omar  staff   128 Dec 29 22:14 train
# drwxr-xr-x@ 4 Omar  staff   128 Dec 29 22:14 valid

# %%
# !pip install ultralytics
# Out:
# ...
# DEPRECATION: pyodbc 4.0.0-unsupported has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pyodbc or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv8 model
model = YOLO("yolov8n.pt")  # Replace 'yolov8n.pt' with the path to your pretrained model file

# Load images from the find-luggage dataset
dataset_yaml = "find-luggage-1/data.yaml"  # Adjust the path to where your data.yaml is located

# Finetune the model on your dataset
# The method name and parameters depend on the Ultralytics library's API
# Replace 'finetune' with the correct method name if it's different
model.train(data=dataset_yaml, epochs=50)  # Adjust training parameters as needed

# Evaluate the model
# Again, this depends on the Ultralytics library's API
# If there's an 'evaluate' method, you can use it; otherwise, you might need to manually evaluate
# model.evaluate(data=dataset_yaml)
# Out:
# New https://pypi.org/project/ultralytics/8.0.231 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.9.7 torch-2.0.0 CPU (Intel Core(TM) i7-7567U 3.50GHz)
# ...

# %%
# Use the model to train on a dataset
model.train("/bag detection/find-luggage-1/data.yaml", epochs=3)  # train the model
metrics = model.evaluate(dataset)  # evaluate model performance on the validation set

results = model.predict("test.png")  # predict on an image
results.save()  # or .show(), .crop(), .pandas(), etc.


# # Use the model
# model.train(data="coco128.yaml", epochs=3)  # train the model
# metrics = model.val()  # evaluate model performance on the validation set
# results = model("https://ultralytics.com/images/bus.jpg")  # predict on an image
# path = model.export(format="onnx")  # export the model to ONNX format
